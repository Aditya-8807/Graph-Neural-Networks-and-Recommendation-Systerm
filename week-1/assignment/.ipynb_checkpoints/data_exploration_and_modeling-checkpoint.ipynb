# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_pickle("submission_data.pkl")

# %%
df.head(5)
# Out:
#    Sno  Lecture  StudentNo  Total_Characters  Total_Words     Submission_Time  \
# 0    1        1         86               195           29 2025-08-01 12:27:27
# 1    2        1        157              1113          200 2025-08-01 12:54:15
# 2    3        1         96              1789          333 2025-08-01 14:48:09
# 3    4        1        107              3102          533 2025-08-01 15:28:08
# 4    5        1        113              2939          460 2025-08-01 16:00:43
#
#    Submission_Delay      x_01      x_02      x_03  ...      x_91      x_92  \
# 0            -41253 -0.077114  0.253333  0.011405  ...  0.337617  0.168170
# 1            -39645 -0.067545  0.227569  0.008495  ...  0.307100  0.149335
# 2            -32811 -0.063024  0.214906  0.007124  ...  0.290288  0.140544
# 3            -30412 -0.048755  0.171059  0.006272  ...  0.229764  0.111833
# 4            -28457 -0.067291  0.227849  0.009686  ...  0.307524  0.149782
#
#        x_93      x_94      x_95      x_96      x_97      x_98      x_99  \
# 0  0.017231  0.159088  0.464630  0.317253  0.096538 -0.298382  0.120905
# 1  0.018137  0.146451  0.420410  0.289732  0.086327 -0.268150  0.107681
# 2  0.018353  0.140202  0.396785  0.271830  0.081143 -0.253906  0.101067
# 3  0.014593  0.110382  0.314830  0.216020  0.063341 -0.200269  0.078878
# 4  0.019012  0.146942  0.422824  0.289825  0.085539 -0.269843  0.108719
#
#       x_100
# 0 -0.077520
# 1 -0.068773
# 2 -0.065998
# 3 -0.052138
# 4 -0.069168
#
# [5 rows x 107 columns]

# %%
df['target'] = (df['Submission_Delay'] > 0).astype(int)
df = df.drop(columns=['Submission_Delay'])
# Out:
# /var/folders/dw/dcpyjh2s1ml5h145lgj8b9hc0000gn/T/ipykernel_95785/826368721.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['target'] = (df['Submission_Delay'] > 0).astype(int)

# %%
print(df['target'].value_counts())
# Out:
# target
# 0    1398
# 1     220
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#      Sno  Lecture  StudentNo  Total_Characters  Total_Words  \
# 927  928        6         18              3521          596
# 571  572        4         91               764          128
# 793  794        5         66              1768          261
# 502  503        4        130              1541          231
# 604  605        4         71              2220          331
#
#         Submission_Time      x_01      x_02      x_03      x_04  ...  \
# 927 2025-08-22 23:55:55 -0.101029  0.359893  0.030867 -0.048351  ...
# 571 2025-08-13 23:17:54 -0.243203  0.284515  0.072583  0.099211  ...
# 793 2025-08-21 00:19:37 -0.236678  0.262542  0.119524 -0.120887  ...
# 502 2025-08-13 19:57:04 -0.184381  0.213504  0.048822  0.074331  ...
# 604 2025-08-13 23:43:08 -0.214937  0.245339  0.059490  0.086775  ...
#
#          x_92      x_93      x_94      x_95      x_96      x_97      x_98  \
# 927  0.108284 -0.091968  0.040283  0.648270  0.375255  0.175256 -0.350403
# 571  0.170311 -0.032417  0.105266  0.623291  0.490932  0.077391 -0.193695
# 793  0.166704 -0.016257  0.062570  0.432651  0.383981  0.082133 -0.335442
# 502  0.123738 -0.033472  0.084244  0.475739  0.377302  0.064096 -0.150198
# 604  0.148880 -0.025737  0.089833  0.540401  0.424842  0.066815 -0.168144
#
#          x_99     x_100  target
# 927  0.174886 -0.115453       1
# 571  0.232558 -0.267878       0
# 793  0.153177 -0.086076       1
# 502  0.183086 -0.204833       0
# 604  0.201955 -0.228437       0
#
# [5 rows x 107 columns]

# %%
df.dtypes
# Out:
# Sno                   int64
# Lecture               int64
# StudentNo             int64
# Total_Characters      int64
# Total_Words           int64
#                      ...
# x_97                float64
# x_98                float64
# x_99                float64
# x_100               float64
# target                int64
# Length: 107, dtype: object

# %%
df.size
# Out:
# 173126

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import StandardScaler

feature_cols = []
for col in df.columns:
    if col.startswith('x_'):
        feature_cols.append(col)
        
X = df[feature_cols]
y = df['target']

# FIX: Changed 'scalar' to 'scaler' to match the next line
scaler = StandardScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])

# %%
print(df[feature_cols[:3]].describe())
# close to zero , acceptable enough
# Out:
#                x_01          x_02          x_03
# count  1.618000e+03  1.618000e+03  1.618000e+03
# mean  -7.026381e-17 -3.074042e-16  1.580936e-16
# std    1.000309e+00  1.000309e+00  1.000309e+00
# min   -3.411581e+00 -2.714986e+00 -1.840512e+00
# 25%   -5.358593e-01 -6.146997e-01 -8.063971e-01
# 50%   -9.496264e-02  1.422680e-01 -1.063301e-01
# 75%    9.356005e-01  6.353760e-01  7.930033e-01
# max    1.905096e+00  2.941827e+00  2.308307e+00

# %%
df.sample(5)
# Out:
#        Sno  Lecture  StudentNo  Total_Characters  Total_Words  \
# 780    781        5         69              2104          360
# 1213  1214        8        184              1029          187
# 931    932        6         21              1014          175
# 776    777        5         14              2677          449
# 1501  1502       11         82              1611          254
#
#          Submission_Time      x_01      x_02      x_03      x_04  ...  \
# 780  2025-08-20 23:58:56 -0.898501  0.371949  0.712943 -1.931954  ...
# 1213 2025-09-03 23:52:53 -2.022925  0.322214  0.562901 -0.178166  ...
# 931  2025-08-22 23:57:16  0.919939  2.063363 -0.601629 -1.097630  ...
# 776  2025-08-20 23:58:13 -0.984582  0.514511  0.824919 -2.014020  ...
# 1501 2025-09-12 14:01:38 -0.157335 -0.160639 -0.247010 -0.330663  ...
#
#           x_92      x_93      x_94      x_95      x_96      x_97      x_98  \
# 780  -0.039640 -0.143884  0.102720 -0.984755  0.727787 -0.868635 -0.430318
# 1213  0.674226  0.555224 -1.719837  0.662179 -1.309517  0.750606 -1.595132
# 931  -0.668090 -2.177263 -0.158470  1.530503  1.125335  0.930628 -0.912038
# 776   0.005830 -0.245429  0.016474 -0.841191  0.936094 -0.744394 -0.542516
# 1501 -0.954569  1.973282 -0.548570 -1.542110 -0.294862 -0.295906  0.779376
#
#           x_99     x_100  target
# 780   0.181270  0.424757       1
# 1213 -0.966584  1.192292       0
# 931   1.060631 -0.333469       1
# 776   0.375301  0.348997       1
# 1501 -1.619525  0.117978       0
#
# [5 rows x 107 columns]

# %%
# Correlation btw features and target var
correlations = df[feature_cols].corrwith(df['target'])
# finding out top 15 features
top_15_features = correlations.abs().nlargest(15).index.tolist()
top_15_features
# Out:
# ['x_04',
#  'x_05',
#  'x_54',
#  'x_74',
#  'x_84',
#  'x_19',
#  'x_52',
#  'x_25',
#  'x_100',
#  'x_38',
#  'x_02',
#  'x_86',
#  'x_48',
#  'x_53',
#  'x_61']

# %%
plt.figure(figsize=(12, 10))
top_15_corr_matrix = df[top_15_features].corr()

# %%
# HeatMAP
import seaborn as sns
sns.heatmap(
    top_15_corr_matrix,
    annot=True,          
    cmap='coolwarm',     
    fmt=".2f",          
    linewidths=0.5,      
    vmin=-1, vmax=1      
)
# Out:
# <Axes: >

# %% [markdown]
# ### Correlation Explanation

# %% [markdown]
# ## Dimensionality Reduction

# %%
from sklearn.manifold import TSNE
import umap
